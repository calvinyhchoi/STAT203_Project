# %% [markdown]
# # Project Proposal
# ##### Group 28 Calvin Choi & Mikel Ibarra Gallardo

# %%
# loading libraries
library(readxl)
library(ggplot2)                     
library(GGally)
library(cowplot)
library(dplyr)
library(gridExtra)
library(repr)
library(infer)
library(repr)
library(tidyverse)
library(tidymodels)

# %% [markdown]
# ## Cleaning Data

# %%
AStat <- read_csv("data/UnitedAirlines_stat.csv", col_names = TRUE) |> # read csv from (INSERT website link here)
         na.omit()                                                     # removing NA values
head(AStat)
# Out:
# New names:
# • `` -> `...1`
# • `Pilots (000)` -> `Pilots (000)...3`
# • `Salaries and Wages (000)` -> `Salaries and Wages (000)...4`
# • `Pilot Training (000)` -> `Pilot Training (000)...5`
# • `Benefits and Payroll Taxes (000)` -> `Benefits and Payroll Taxes (000)...6`
# • `Per Diem/ Personnel (000)` -> `Per Diem/ Personnel (000)...7`
# • `Purchased Goods (000)` -> `Purchased Goods (000)...8`
# • `Fuel/Oil (000)` -> `Fuel/Oil (000)...9`
# • `Insurance (000)` -> `Insurance (000)...10`
# • `Other (inc. Tax) (000)` -> `Other (inc. Tax) (000)...11`
# • `Maintenance (000)` -> `Maintenance (000)...12`
# • `Labor (000)` -> `Labor (000)...13`
# • `Materials (000)` -> `Materials (000)...14`
# • `Third Party (000)` -> `Third Party (000)...15`
# • `Total Direct (000)` -> `Total Direct (000)...16`
# • `Burden (000)` -> `Burden (000)...17`
# • `Aircraft Ownership (000)` -> `Aircraft Ownership (000)...18`
# • `Rentals (000)` -> `Rentals (000)...19`
# ...

# %% [markdown]
# ## Wrangling Data

# %%
AStat <- AStat   |>           #transpose the dataset so years are observations
         
        select(...1, Aircraft Days...145, )  #      |>         #
AStat
# Out:
# Error in `select()`:
# ! Can't subset columns that don't exist.
# ✖ Column `Aircraft Days...145` doesn't exist.
# Traceback:
#
# 1. select(AStat, ...1, "Aircraft Days...145")
# 2. select.data.frame(AStat, ...1, "Aircraft Days...145")
# 3. tidyselect_fix_call(tidyselect::eval_select(expr(c(...)), .data),
#  .     call = error_call)
# 4. withCallingHandlers(expr, error = function(cnd) {
#  .     cnd$call <- call
#  .     cnd$parent <- NULL
#  .     cnd_signal(cnd)
#  . })
# 5. tidyselect::eval_select(expr(c(...)), .data)
# 6. eval_select_impl(data, names(data), as_quosure(expr, env), include = include,
#  .     exclude = exclude, strict = strict, name_spec = name_spec,
#  .     allow_rename = allow_rename, error_call = error_call, )
# 7. with_subscript_errors(vars_select_eval(vars, expr, strict = strict,
#  .     data = x, name_spec = name_spec, uniquely_named = uniquely_named,
#  .     allow_rename = allow_rename, type = type, error_call = error_call),
#  .     type = type)
# ...
